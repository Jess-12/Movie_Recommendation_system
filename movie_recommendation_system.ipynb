# %% [markdown]
# <a href="https://colab.research.google.com/github/Jess-12/Movie_Recommendation_system/blob/main/movie_recommendation_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import dependencies

# %%
import numpy as np
import pandas as pd
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
data_movie= pd.read_csv('/content/movies.csv')

# %%
data_movie.head()
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
# 2      2  245000000                    Action Adventure Crime
# 3      3  250000000               Action Crime Drama Thriller
# 4      4  260000000          Action Adventure Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# ...

# %%
data_movie.shape
# Out:
# (4803, 24)

# %%
#selecting relevant features 
selected_data=['genres','keywords','popularity','cast','director','tagline']
print(selected_data)
# Out:
# ['genres', 'keywords', 'popularity', 'cast', 'director', 'tagline']

# %% [markdown]
# replacing all null values with null string

# %%
for feature in selected_data:
  data_movie[feature]= data_movie[feature].fillna('')

# %%
#combining selected features
combined_feature= data_movie['genres']+''+data_movie['keywords']+''+data_movie['tagline']+''+data_movie['title']+''+data_movie['cast']+''+data_movie['director']
print(combined_feature)
# Out:
# 0       Action Adventure Fantasy Science Fictioncultur...
# 1       Adventure Fantasy Actionocean drug abuse exoti...
# 2       Action Adventure Crimespy based on novel secre...
# 3       Action Crime Drama Thrillerdc comics crime fig...
# 4       Action Adventure Science Fictionbased on novel...
#                               ...
# 4798    Action Crime Thrillerunited states\u2013mexico...
# 4799    Comedy RomanceA newlywed couple's honeymoon is...
# 4800    Comedy Drama Romance TV Moviedate love at firs...
# 4801    A New Yorker in ShanghaiShanghai CallingDaniel...
# 4802    Documentaryobsession camcorder crush dream gir...
# Length: 4803, dtype: object

# %%
vectorize=TfidfVectorizer()
vector_data=vectorize.fit_transform(combined_feature)
print(vector_data)
# Out:
#   (0, 4316)	0.17025221801883436
#   (0, 24282)	0.2667685233028317
#   (0, 19403)	0.15512064793418184
#   (0, 16972)	0.21789049631386714
#   (0, 27215)	0.16151542115770343
#   (0, 31105)	0.19130283844786003
#   (0, 26237)	0.2099225918047785
#   (0, 25103)	0.2099225918047785
#   (0, 32284)	0.19394534139872813
#   (0, 31861)	0.2287225808580658
#   (0, 2016)	0.2667685233028317
#   (0, 21695)	0.25445469973493695
#   (0, 21216)	0.07292947700390828
#   (0, 31825)	0.12162833164013258
#   (0, 28349)	0.058080304733987974
#   (0, 26616)	0.2667685233028317
#   (0, 5591)	0.23894111674289278
#   (0, 30839)	0.1266090406432436
#   (0, 26778)	0.3249592344839965
#   (0, 11816)	0.16012420269491529
#   (0, 5322)	0.21235345887688567
#   (0, 10810)	0.2667685233028317
#   (0, 25484)	0.09708587285108575
#   (0, 10423)	0.11500505700221522
#   (0, 617)	0.08869223925359991
#   :	:
#   (4801, 32254)	0.2867796942556018
#   (4801, 9491)	0.24917675330614356
#   (4801, 971)	0.1859984029803072
# ...

# %%
#getting similarity score using cosine similarity
similarity= cosine_similarity(vector_data)
print(similarity.shape)
# Out:
# (4803, 4803)

# %%
movie_name= input("Enter the favourite movie name: ")
# Out:
# Enter the favourite movie name: iron man

# %%
#creating a list with all movie names
all_titles= data_movie['title'].tolist()
print(all_titles)
# Out:
# ['Avatar', "Pirates of the Caribbean: At World's End", 'Spectre', 'The Dark Knight Rises', 'John Carter', 'Spider-Man 3', 'Tangled', 'Avengers: Age of Ultron', 'Harry Potter and the Half-Blood Prince', 'Batman v Superman: Dawn of Justice', 'Superman Returns', 'Quantum of Solace', "Pirates of the Caribbean: Dead Man's Chest", 'The Lone Ranger', 'Man of Steel', 'The Chronicles of Narnia: Prince Caspian', 'The Avengers', 'Pirates of the Caribbean: On Stranger Tides', 'Men in Black 3', 'The Hobbit: The Battle of the Five Armies', 'The Amazing Spider-Man', 'Robin Hood', 'The Hobbit: The Desolation of Smaug', 'The Golden Compass', 'King Kong', 'Titanic', 'Captain America: Civil War', 'Battleship', 'Jurassic World', 'Skyfall', 'Spider-Man 2', 'Iron Man 3', 'Alice in Wonderland', 'X-Men: The Last Stand', 'Monsters University', 'Transformers: Revenge of the Fallen', 'Transformers: Age of Extinction', 'Oz: The Great and Powerful', 'The Amazing Spider-Man 2', 'TRON: Legacy', 'Cars 2', 'Green La
# ...

# %%
# finding close match with the given user movie name
find_close_match= difflib.get_close_matches(movie_name,all_titles)
print(find_close_match)
# Out:
# ['Iron Man', 'Iron Man 3', 'Iron Man 2']

# %%
close_match= find_close_match[0]
print(close_match)
# Out:
# Iron Man

# %%
movie_index = data_movie[data_movie.title==close_match]['index'].values[0]
print(movie_index)
# Out:
# 68

# %%
#getting list of similar movies
similarity_score= list(enumerate(similarity[movie_index]))
print(similarity_score)
# Out:
# [(0, 0.014037931750385708), (1, 0.029199282202832164), (2, 0.005689104003652788), (3, 0.005575363904356829), (4, 0.013800629716128946), (5, 0.005377657533541642), (6, 0.04767486077195642), (7, 0.11127568784667947), (8, 0.0), (9, 0.03099170075761052), (10, 0.015846543323771115), (11, 0.004893416869436823), (12, 0.0), (13, 0.005083368564703271), (14, 0.04109148412950095), (15, 0.0), (16, 0.15855250606929744), (17, 0.004922576133901604), (18, 0.0131733320324413), (19, 0.004428689128107004), (20, 0.060987983704164646), (21, 0.0048041987481996645), (22, 0.0), (23, 0.0), (24, 0.0), (25, 0.0), (26, 0.12733439361073018), (27, 0.013035062480670517), (28, 0.05121051327092074), (29, 0.00568702078537083), (30, 0.0642454102097715), (31, 0.2314178575098231), (32, 0.01733405601765676), (33, 0.1121630487018926), (34, 0.0), (35, 0.028266321768711175), (36, 0.0249024025548942), (37, 0.0), (38, 0.08966691368581914), (39, 0.07001262654746183), (40, 0.0), (41, 0.013278349166936265), (42, 0.0), (43, 0.027
# ...

# %%
#sorting based on similarity score
sorted_similar_movie= sorted(similarity_score,key = lambda x:x[1], reverse= True)
print(sorted_similar_movie)
# Out:
# [(68, 1.0000000000000002), (79, 0.24245080193088528), (31, 0.2314178575098231), (16, 0.15855250606929744), (26, 0.12733439361073018), (33, 0.1121630487018926), (7, 0.11127568784667947), (203, 0.10567243495572347), (46, 0.1054479674886666), (511, 0.10470685982373404), (3623, 0.10413850889956369), (174, 0.10029125775492005), (64, 0.09407970968735076), (353, 0.09109081441673289), (101, 0.09007739753405916), (38, 0.08966691368581914), (788, 0.08927522255833094), (1406, 0.08473060373110385), (3166, 0.08403886405982683), (1210, 0.08197552919275639), (2186, 0.08059913588201659), (3160, 0.0790728660775499), (1282, 0.0778758715887364), (3443, 0.07776106557506915), (182, 0.0771689461976532), (307, 0.07552312953970414), (85, 0.07424422082053096), (783, 0.07416639855376483), (2235, 0.0739115088482302), (3749, 0.07383764597326968), (2066, 0.07333678137981622), (4542, 0.07303376935429692), (4033, 0.07228723650749819), (2868, 0.07056528238178597), (39, 0.07001262654746183), (1553, 0.069600021670662
# ...

# %%
#printing name of similar mvoies
print('movies recommened : ' )
i=1
for movie in sorted_similar_movie:
  index= movie[0]
  title_from_movie= data_movie[data_movie.index==index]['title'].values[0]
  if i<20:
    print(i,'.',title_from_movie)
    i=i+1
# Out:
# movies recommened :
# 1 . Iron Man
# 2 . Iron Man 2
# 3 . Iron Man 3
# 4 . The Avengers
# 5 . Captain America: Civil War
# 6 . X-Men: The Last Stand
# 7 . Avengers: Age of Ultron
# 8 . X2
# 9 . X-Men: Days of Future Past
# 10 . X-Men
# 11 . Made
# 12 . The Incredible Hulk
# 13 . X-Men: Apocalypse
# 14 . Tropic Thunder
# 15 . X-Men: First Class
# 16 . The Amazing Spider-Man 2
# 17 . Deadpool
# 18 . The Nativity Story
# 19 . The Best Man

# %% [markdown]
# MOVIE RECOMMENDATION SYSTEM:

# %%
movie_name= input("Enter the favourite movie name: ")

all_titles= data_movie['title'].tolist()

find_close_match= difflib.get_close_matches(movie_name,all_titles)

close_match= find_close_match[0]

movie_index = data_movie[data_movie.title==close_match]['index'].values[0]

similarity_score= list(enumerate(similarity[movie_index]))

sorted_similar_movie= sorted(similarity_score,key = lambda x:x[1], reverse= True)

print('movies recommened : ' )
i=1
for movie in sorted_similar_movie:
  index= movie[0]
  title_from_movie= data_movie[data_movie.index==index]['title'].values[0]
  if i<20:
    print(i,'.',title_from_movie)
    i=i+1
# Out:
# Enter the favourite movie name: batman
# movies recommened :
# 1 . Batman
# 2 . Batman Returns
# 3 . Batman & Robin
# 4 . Batman Begins
# 5 . Beetlejuice
# 6 . Man of Steel
# 7 . Jonah Hex
# 8 . The Dark Knight
# 9 . Superman Returns
# 10 . The Dark Knight Rises
# 11 . A History of Violence
# 12 . Pale Rider
# 13 . The New Guy
# 14 . Superman
# 15 . Superman III
# 16 . 8 Mile
# 17 . Catwoman
# 18 . Bedazzled
# 19 . Batman
